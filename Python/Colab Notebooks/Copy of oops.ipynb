# %%
#class object

# %%
class home:
  x = 9
#object
print(obj.x)
obj2 = home()
print(obj2.x)
# Out:
# 9
# 9

# %%
class add:
  name = "steve" #class variable
  def __init__(self,x,y):
    self.x = x
    self.y = y

  def sum(self):
    return self.x + self.y

object1 = add(8,9)
print(object1)
print(object1.name)
object1.sum()
# Out:
# ...
# steve
# 17

# %%
object2 = add(10,88)
print(object2.sum())
# Out:
# 98

# %%
class add:
  pass
