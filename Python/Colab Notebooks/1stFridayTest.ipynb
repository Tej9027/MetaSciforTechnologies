# %%
# The RTO (Regional Transport Office) website holds a registration form which is responsible for registering a user for a Driving License.
# The RTO wants to take the next step if and only if the user's age is greater than or equal to 18.
# Scenario 1 : When Traffic Light is Red
# Jake, a 20 year old teenager has learnt to ride a bike and is a bit confused with the traffic signals. He doesn't know what to do when the signal is red.
# So In this scenario Jake should just know what Jake should do when the signal is red whether he should leave or stop.
# So Write a If-Else condition to guide Jake
jake_age = 20

# %%
jake_age = 20
if jake_age >=18:
  print("you can fill a form for driving license")
else:
  print("you can't fill a form for driving license")
traffic_signal = "red"
if traffic_signal == "red":
    print("Jake should stop on red signal.")
else:
    print("Jake should go.")
# Out:
# you can fill a form for driving license
# Jake should stop.

# %%
# Mary, a 15 year old girl, was watching her mom making a budget list every month, either her mom use to forget few things or
# she use to go out of budget due to no proper grocery list that says quantity of items, prices and stuff.
# So Mary wants to help her mom in managing the monthly groceries by creating an app that takes grocery item name, item price and quantity of item.
# Before all this, the app is suppose to accept the budget amount, if shopping list items price cross over the budget amount then any new items should not be added to the list.
# There should be 2 things in the menu of the app one to add an item and the second option to exit from the menu once the add item is chosen, then the item name, item quantity
# and item price should be accepted and the price should be checked with the budget amount. If the item amount is crossing the budget amount then the item cannot be added to the list.
# If the exit option is chosen then the total budget amount and the list of items should be displayed.
budget_amount= float(input("enter the budget amount: "))
balance = 0
items = []
while True:
  print("1. Add item")
  print("2. Exit")
  choice = int(input("enter your choice: "))
  if choice == 1:
    item_name = input("enter the item name: ")
    item_price = float(input("enter the item price: "))
    item_quantity = int(input("enter the item quantity: "))
    total_price = item_price * item_quantity
    if total_price * balance > budget_amount:
      print("item cannot be added to the list.")
    else:
      balance = balance + total_price
      items.append((item_name, item_quantity, item_price))
      print(f"item {item_name} added to the list.")
  elif choice == 2:
    print("total budget amount:", balance)
    print("items in the list:")
    for item in items:
      print(item)
    break
  else:
    print("invalid choice. Please try again.")
# Out:
# enter the budget amount: 100
# 1. Add item
# 2. Exit
# enter your choice: 1
# enter the item name: milk
# enter the item price: 65
# enter the item quantity: 1
# item milk added to the list.
# 1. Add item
# 2. Exit
# enter your choice: 2
# total budget amount: 65.0
# items in the list:
# ('milk', 1, 65.0)

# %%
# Sameer, a resident of India met John, a resident of california on facebook and they became friends, just in a conversation they planned to know each other's
# height and there was a problem, John would understand only if told in centimeter(cm) format. So write a program to help John to understand Sameer’s height in python to convert Feet & Inches To CM
sameer_height_feet = float(input("enter the height of sameer in feet: "))
sameer_height_inches = float(input("enter the height of sameer in inches: "))
height_in_cm = sameer_height_feet * 30.48 + sameer_height_inches * 2.54
print(height_in_cm)
# Out:
# enter the height of sameer in feet: 5
# enter the height of sameer in inches: 76
# 345.44
