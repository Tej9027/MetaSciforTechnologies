# %%
#generators and decorators

# %%
# print()
# return
# yield

# %%
def task_Of_Generator():
  yield 1
  yield 33
  yield 90
res = task_Of_Generator()
print(next(res))
print(next(res))
print(next(res))
# Out:
# 1
# 33
# 90

# %%
#fibonacci series

# %%
#
Generator1 = (i for i in range(5) if i%2==0)

for i in Generator1:
  print(i)
# Out:
# 0
# 2
# 4

# %%
#decorators @


@sub
def add(a,b):
  def

# %%
@bark
def catsound():
  print("meow")

# %%
name 1

@name("name 1")
name = "hi"

# %%
#decorators symbols is @
#decorators uses @decorator_name

# %%
def mydecorator(func):
    def wrapper():
      print("before calling function")
      func()
      print("after calling function")
    return wrapper
def mydecorator(func):
    def wrapper():
      print("before calling function")
      func()
      print("after calling function")
    return wrapper

@decorator1
@mydecorator #stack
def task():
  print(" Hi decorator ")

task()
# Out:
# before calling function
#  Hi decorator
# after calling function

# %%
def decorator1(func):
    def wrapper():
      print("before calling function")
    return wrapper
# def decorator2(func):
#     def wrapper():
#       print("before calling function2")

#     return wrapper
# def decorator3(func):
#     def wrapper():
#       print("before calling function")

    #return wrapper
@decorator1
@dec


    #lifo
def function():
  print("hi")
function()
# Out:
# before calling function

# %%
def dec1_calls_dec2(func):
  decor = decorator1(decorator2(func))
  return decorated

@dec1_calls_dec2
def newtask():
