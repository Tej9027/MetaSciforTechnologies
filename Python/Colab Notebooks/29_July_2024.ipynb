# %% [markdown]
# Yash now learned how he could use inheritance to create a square class
# with the help of the existing rectangle class. Now with the help of method
# overriding, he wants to change the side of the squares as well. He just
# need to redefine the method setLength( ) and setBreadth( ).

# %%
class rectangle:
  def __inti__(self):
    self.length=0
    self.breadth=0

  def setLength(self,length):
    self.length=length

  def setBreadth(self,breadth):
    self.breadth=breadth

  def getDimensions(self):
    return (self.length, self.breadth)


class square(rectangle):
  def setLength(self, length):
    self.length=length
    self.breadth=length

  def setBreadth(self, breadth):
    self.length=breadth
    self.breadth=breadth

Rectangle = rectangle()
Rectangle.setLength(10)
Rectangle.setBreadth(5)
print(Rectangle.getDimensions())
Square = square()
Square.setLength(10)
print(Square.getDimensions())
Square.setBreadth(5)
print(Square.getDimensions())
# Out:
# (10, 5)
# (10, 10)
# (5, 5)

# %% [markdown]
# TASK2- Vehicle Problem:
# In a town, a garage owner manages cars and motorcycles. The owner
# needs a program to track vehicle operations. Cars honk when started;
# motorcycles pop wheelies when started. The owner wants to start and
# stop vehicles as requested. Instructions for the code: Create a Python
# program with classes for Vehicle, Car, and Motorcycle as shown. Define
# attributes and methods for starting and stopping vehicles. Create
# instances of Car and Motorcycle. Demonstrate starting, performing
# vehicle-specific actions, and stopping both instances. Ensure the
# program runs without errors and showcases vehicle functionalities.

# %%
class Vehicle:
    def __init__(self, name):
        self.name = name
        self.is_running = False

    def start(self):
        self.is_running = True
        print(f"{self.name} is starting.")

    def stop(self):
        self.is_running = False
        print(f"{self.name} is stopping.")

class Car(Vehicle):
    def __init__(self, name):
        super().__init__(name)

    def start(self):
        super().start()
        self.honk()

    def honk(self):
        if self.is_running:
            print("Car is honking: Beep Beep Beep Beep!")

class Motorcycle(Vehicle):
    def __init__(self, name):
        super().__init__(name)

    def start(self):
        super().start()
        self.pop_wheelie()

    def pop_wheelie(self):
        if self.is_running:
            print("Motorcycle is popping a wheelie!")

my_car = Car("Sedan")
my_motorcycle = Motorcycle("Harley")

print("Starting the car.")
my_car.start()
print("Stopping the car.")
my_car.stop()

print("\nStarting the motorcycle.")
my_motorcycle.start()
print("Stopping the motorcycle.")
my_motorcycle.stop()
# Out:
# Starting the car.
# Sedan is starting.
# Car is honking: Beep Beep Beep Beep!
# Stopping the car.
# Sedan is stopping.
#
# Starting the motorcycle.
# Harley is starting.
# Motorcycle is popping a wheelie!
# Stopping the motorcycle.
# Harley is stopping.
