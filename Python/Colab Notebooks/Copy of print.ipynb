# %%
print("hi") #fdggdgd comment

# %%
#Data Types

# "farzana22444@$$$$" String

# 25 int

# 7.9 float

# True boolean

# %%
#variables

# x = 8 #variable vary the values
# print(x)

# %%
# letter or a underscore

# you cant start it with digits

# _name = "ffff"
# print(_name)

# %%
Name = "gggg"
print(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f4b50c69f2fa> in <cell line: 2>()
#       1 Name = "gggg"
# ----> 2 print(name)
#
# NameError: name 'name' is not defined

# %%
# num = input("enter number") #string

num = int(input("enter number"))
print(num)
# Out:
# enter number9.7
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-0253442e00d9> in <cell line: 3>()
#       1 # num = input("enter number") #string
#       2
# ----> 3 num = int(input("enter number")) #string
#       4 print(num)
#
# ValueError: invalid literal for int() with base 10: '9.7'

# %%
num = float(input("enter number")) #string
print(num)
# Out:
# enter number9
# 9.0

# %%
x = "2"
print(int(x))
# Out:
# 2

# %%
x = "2"
print(float(x))
# Out:
# 2.0

# %%
x = 2
r = str(x)
print(str(x))
print(type(r))
# Out:
# 2
# <class 'str'>

# %%
print("hi")
print("bye")
# Out:
# hi
# bye

# %%
one = "1"
two = "2"
print(one + two) #concatenation operator combining two strings
# Out:
# 12

# %%
one = 1
two = 2
print(one + two)
# Out:
# 3

# %%
print("hi\nbye")
print()
print("*")
print("**")
print("***")
print("****")
# Out:
# hi
# bye
#
# *
# **
# ***
# ****

# %%
print("\ ")
# Out:
# \

# %%
#operators
#Arithmetic +,-,*,/,%,//,**,++,--

# %%
x = 8
y = 9
print(x+y)
# Out:
# 17

# %%
x = 8
y = 9
print(x-y)
print(x*y)
print(x/y)
# Out:
# -1
# 72
# 0.8888888888888888

# %%
x = 4
y = 2
print(4%2)
# Out:
# 0

# %%
x = 4
y = 2
print(4//2) #floor operator

# %%
print(2**2)
# Out:
# 4

# %% [markdown]
# 2*2 = 4

# %%
z = 4
z = z+1 # or z += 1
print(z)
# Out:
# 5

# %%
z = 4
z -= 1
print(z)
# Out:
# 3

# %%
#logical operator and or not

# %%
# email = "pdt@scifortechnologies.com"
# password = "@123"
# em = input("enter email ")
# pass1 = input("enter password ")
# if em == email and pass1 == password:
#   print("you are authorized ")
# else:
#   print("check you email or password")
# Out:
# enter email pdt@scifortechnologies.com
# enter password @123
# you are authorized

# %%
email = "pdt@scifortechnologies.com"
password = "@123"
em = input("enter email ")
pass1 = input("enter password ")
if em == email or pass1 == password:
  print("you are authorized ")
else:
  print("check you email or password")
# Out:
# enter email hhhd
# enter password @123
# you are authorized

# %%
x = True
print(not x) #reversing
# Out:
# True

# %%
#comparison operator

# > < >= <= != ==

num1 = int(input("enter number : "))
num2 = int(input("enter second number : "))

if num1>num2:
  print("num1 is greater than num2")
elif num2>num1:
  print("num2 is greater than num1")
else:
  print("both are equal")
# Out:
# enter number : 777777
# enter second number : 777777
# both are equal

# %%
#assignment  and other

# %%
name = "ghhdhhd"
if "f" in name:
  print("yes")
else:
  print("no")
# Out:
# no

# %%
# name or _
# name
# print(Name)

name = input("enter name ")
phone_number = int(input("enter phone number "))
emailid = input("enter email ")

print("dominos hajjajajajaj hi ",name,"ghshhshsh your phone number is ",phone_number,"your email id is ",emailid)
# Out:
# enter name farzana rashid
# enter phone number 92727737373
# enter email faraffa@gmail.com
# dominos hajjajajajaj hi  farzana rashid ghshhshsh your phone number is  92727737373 your email id is  faraffa@gmail.com

# %%
num = input("")
reverse = num[::-1]
if num == reverse:
  print("pallindrome")
else:
  print("not pallindrome")
# Out:
# gdggd
# not pallindrome
