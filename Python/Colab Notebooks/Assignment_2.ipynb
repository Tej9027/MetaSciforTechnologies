# %% [markdown]
# In a classroom, there are desks arranged in a row and column fashion. The math teacher, Mr. James, asked one of the kid whose name was Robert to count the total number of desks present in the class. Robert was just wondering if there is software that could take the number of rows and number of columns and show how many desks there are that would make his job easier. So write a python program to help Robert to count the number of desks present in the class.Person Arrival Detector For James

# %%
rows = int(input("enter the no. of rows: "))
columns = int(input("enter the no. of columns: "))
desks = rows * columns
print("The total number of desks in the class is:", desks)

# %% [markdown]
# Mr James, A businessman in canada was throwing a small party in a banquet hall and wanted to track the number of people attended the party so he kept a people tracker device in the entrance where every person enters is supposed to enter his or her authorization code to enter the hall, certain codes were assigned they are as follows :
# If Banquet Hall Team Members like Manager, waiter, and Mr. James himself then their authorization code will be : 0
# If Guests Their Authorization Code Will be : 1
# If the Authorization Code Entered is 1 then increment the number_of_guests Variable by 1, Wish the Guest like
# "Door Opened"
# "Welcome to the Party, We Hope you have fun."
# else If the Authorization Code Entered is 0 then print as follows
# "Access Granted"
# "Door Opened"
# else tell the person that his entered number is invalid

# %%
number_of_guests = 0
authorization_code = int(input("Enter the authorization code: "))
if authorization_code == 0:
    print("Access Granted.\n Door Openend.")
elif authorization_code == 1:
    number_of_guests += 1
    print("Door Opened.\n Welcome to the Party, We Hope you have fun.")
else:
    print("Invalid Authorization Code. PLease Use valid Authorization Code.")
# Out:
# Enter the authorization code: 2
# Invalid Authorization Code. PLease Use valid Authorization Code.

# %% [markdown]
# Mathew, a 13 year old kid, is good at math but whenever it comes to the even and odd numbers he always faces difficulty to find the even or odd number greater than 10. So write a python program to help Mathew to print odd and even numbers in a certain range using a for loop.

# %%
first_range = int(input("Enter the starting number of the range: "))
last_range = int(input("Enter the ending number of the range: "))

print(f"Even numbers between {first_range} and {last_range}:")
for number in range(first_range, last_range + 1):
    if number % 2 == 0:
        print(number, end=",")

print(f"\nOdd numbers between {first_range} and {last_range}:")
for number in range(first_range, last_range + 1):
    if number % 2 != 0:
        print(number, end=",")
# Out:
# Enter the starting number of the range: 20
# Enter the ending number of the range: 50
# Even numbers between 20 and 50:
# 20,22,24,26,28,30,32,34,36,38,40,42,44,46,48,50,
# Odd numbers between 20 and 50:
# 21,23,25,27,29,31,33,35,37,39,41,43,45,47,49,

# %% [markdown]
# An online essay writing competition was held in a school. The students were required to write at least 250 words. According to the rule, only that essay should be checked which contains at least 250 words. Teachers were just guessing the number of words in the essay but that was not an accurate way to count the number of words. So write a program that can count the number of words in an essay ( Hint: Take input and count the number of words using for loop | Note: to count the number of words you can just count the number of blank spaces given in the input. )

# %%
number_of_words = 0
essay = input("Enter an Essay: ")
for i in essay:
    if i == " ":
      number_of_words += 1
print("The number of words in the essay is:", number_of_words)
# Out:
# Enter an Essay: Artificial Intelligence (AI) is revolutionizing various sectors, significantly impacting society in profound ways. From healthcare to transportation, AI is enhancing efficiency, accuracy, and innovation, thereby transforming how we live and work.  In healthcare, AI systems can analyze vast amounts of medical data to diagnose diseases more accurately and at an early stage. For instance, AI algorithms can detect abnormalities in medical imaging with precision, supporting doctors in providing better patient care. Furthermore, AI-driven predictive analytics can anticipate disease outbreaks, contributing to improved public health responses and potentially saving countless lives.  The transportation industry has also experienced a paradigm shift due to AI. Autonomous vehicles, powered by sophisticated AI algorithms, promise to reduce traffic accidents and improve fuel efficiency. By managing traffic flow more effectively, AI can mitigate congestion and decrease pollution levels, contributing to a cleaner environment. Additionally, AI in logistics optimizes supply chains, reducing costs and ensuring timely delivery of goods.  However, the rise of AI brings challenges. Job displacement is a significant concern as automation replaces roles traditionally held by humans. While AI creates new job opportunities, the transition requires reskilling and adaptation. Ethical considerations are paramount, particularly regarding privacy, security, and the potential for AI bias, which can perpetuate and even exacerbate existing societal inequalities.  In conclusion, AI's impact on society is multifaceted, offering transformative benefits while posing critical challenges. As AI continues to evolve, it is crucial for society to navigate its implications thoughtfully, ensuring that technological advancements align with ethical standards and contribute to the greater good. Balancing innovation with responsibility will be key to harnessing the full potential of AI for a better future.
# The number of words in the essay is: 273

# %%
number_of_blankspaces = 0
number_of_words = 0
essay = input("Enter an Essay: ")
for i in essay:
    if i == " ":
      number_of_blankspaces += 1
if number_of_blankspaces >= 250:
  print("The essay contains at least 250 words.")
  print("The number of blank spaces in the essay is:", number_of_blankspaces)
else:
  print("The essay does not contain at least 250 words.")
# Out:
# Enter an Essay: Artificial Intelligence (AI) is revolutionizing various sectors, significantly impacting society in profound ways. From healthcare to transportation, AI is enhancing efficiency, accuracy, and innovation, thereby transforming how we live and work.  In healthcare, AI systems can analyze vast amounts of medical data to diagnose diseases more accurately and at an early stage. For instance, AI algorithms can detect abnormalities in medical imaging with precision, supporting doctors in providing better patient care. Furthermore, AI-driven predictive analytics can anticipate disease outbreaks, contributing to improved public health responses and potentially saving countless lives.  The transportation industry has also experienced a paradigm shift due to AI. Autonomous vehicles, powered by sophisticated AI algorithms, promise to reduce traffic accidents and improve fuel efficiency. By managing traffic flow more effectively, AI can mitigate congestion and decrease pollution levels, contributing to a cleaner environment. Additionally, AI in logistics optimizes supply chains, reducing costs and ensuring timely delivery of goods.  However, the rise of AI brings challenges. Job displacement is a significant concern as automation replaces roles traditionally held by humans. While AI creates new job opportunities, the transition requires reskilling and adaptation. Ethical considerations are paramount, particularly regarding privacy, security, and the potential for AI bias, which can perpetuate and even exacerbate existing societal inequalities.  In conclusion, AI's impact on society is multifaceted, offering transformative benefits while posing critical challenges. As AI continues to evolve, it is crucial for society to navigate its implications thoughtfully, ensuring that technological advancements align with ethical standards and contribute to the greater good. Balancing innovation with responsibility will be key to harnessing the full potential of AI for a better future.
# The essay contains at least 250 words.
# The number of blank spaces in the essay is: 273

# %% [markdown]
# Create  a program that find the number is prime number or not.

# %%
n = int(input("Enter a number: "))
if n > 1:
  for i in range(2, n):
    if (n % i) == 0:
      print(n, "is not a prime number")
      break
  else:
    print(n, "is a prime number")
# Out:
# Enter a number17
# 17 is a prime number
