# %%
# Q1. Arvind just started learning python and he is very interested to know how he can print his name on the screen using python.
# Write a program to print Arvind on the screen. Print your name and age as well using a python print statement.
# Sol.
print("My Name is Arvind and my age is 24.")
# Out:
# My Name is Arvind and my age is 24.

# %%
# Himanshi is confused with different shapes. Write a program in python to print different shapes using these symbols: “|”, “-”, “/”, “\”.
# Sol.
print("Rectangle")
print("|------------|")
print("|            |")
print("|            |")
print("|            |")
print("|            |")
print("|            |")
print("|            |")
print("|            |")
print("|------------|")

print("Diamond")
print("    /\\    ")
print("   /  \\   ")
print("  /    \\  ")
print(" /      \\ ")
print("/        \\")
print("\\        /")
print(" \\      / ")
print("  \\    /  ")
print("   \\  /   ")
print("    \\/    ")

print("Triangle")
print("    /\\    ")
print("   /  \\   ")
print("  /    \\  ")
print(" /      \\ ")
print("/--------\\")

print("Shape")
print("|\\\//|")
print("--||--")
print("__/\\__")
# Out:
# Rectangle
# |------------|
# |            |
# |            |
# |            |
# |            |
# |            |
# |            |
# |            |
# |------------|
# Diamond
#     /\
#    /  \
#   /    \
#  /      \
# /        \
# \        /
#  \      /
#   \    /
#    \  /
#     \/
# Triangle
#     /\
#    /  \
#   /    \
#  /      \
# /--------\
# Shape
# |\\//|
# --||--
# __/\__

# %%
# Sahil challenged Chirag to print the names of his friend in different lines using a single print statement.
# Sahil thought that this would be impossible to do. To help Chirag write a python program to print the names
# of your five friends in five different lines using a single print statement.
names = "Nikhil\nArpit\nPradumn\nRohit\nMukul"
print(names)
# Out:
# Nikhil
# Arpit
# Pradumn
# Rohit
# Mukul

# %%
# A teacher told students to write an essay on themselves. Nidhi created a python program that can generate an essay just by taking inputs.
# She shared the program with her friends to help them. Write a python program that can take inputs like name, age, address, etc, and convert it into an essay.
name = input("Enter your name: ")
age = input("Enter your age: ")
address = input("Enter your address: ")
hobbies = input("Enter your hobbies (separate by commas): ")
favorite_subject = input("Enter your favorite subject: ")
print(f"Hi, I am {name}. I am {age} years old. I live in {address}. My hobbies are {hobbies}. My favorite subject is {favorite_subject}.")
# Out:
# Enter your name: Aditi
# Enter your age: 24
# Enter your address: Bijnor, Uttar Pradesh
# Enter your hobbies (separate by commas): Chess, Travel, Learning new things
# Enter your favorite subject: Data Structure
# Hi, I am Aditi. I am 24 years old. I live in Bijnor, Uttar Pradesh. My hobbies are Chess, Travel, Learning new things. My favorite subject is Data Structure.

# %%
# Rakshita wants to create a simple chatbot using python language. Write a program in python to help Rakshita in creating the chatbot.
# ● Hint: with the help of variables store the answers of the user and use it for further conversation by the chatbot.
# ● Example : ● >> ● Hi, I am a chatbot. What is your name? ● >>Nidhi
# ● Oh, Nidhi in which grade you are right now? ● >>8 ● Nidhi you are in 8th grade. Can I ask you one question? yes or no?
# ● >>yes ● Tell me 1024+98=? ● >>1122 ● Good! Your answer is correct. Bye ● >>bye
print("Hi, I am a chatbot.")
print("What is your name?")
Name = input("Enter your name: ")
print(f"Oh, {Name} in which grade you are right now?")
grade = int(input("Enter your grade: "))
print(f"{Name} you are in {grade} grade. Can I ask you one question? yes or no?")
if input("Enter your answer: ") == "yes":
    print("Tell me 1024+98=?")
    answer = int(input("Enter your answer: "))
    if answer == 1122:
      print("Good! Your answer is correct. Bye")
    else:
      print("Sorry, wrong answer. Bye")
else:
    print("Bye. Have a nice day.")
# Out:
# Hi, I am a chatbot.
# What is your name?
# Enter your name: Nidhi
# Oh, Nidhi in which grade you are right now?
# Enter your grade: 5
# Nidhi you are in 5 grade. Can I ask you one question? yes or no?
# Enter your answer: yes
# Tell me 1024+98=?
# Enter your answer: 1122
# Good! Your answer is correct. Bye

# %%
# Himanshu sells notebooks. Sometimes it becomes a bit difficult for him to calculate the total amount to charge from the customer.
#To help Himanshu create a program that asks the user to enter the number of books to buy and then print the amount to be paid. ● Hint: Assume the cost of one notebook - $2
No_of_Books = input("Enetr the no. of books.")
print("The cost of one notebook - $2.")
print(f"So the Totoal amount to be paid is {int(No_of_Books)*2}$.")
# Out:
# Enetr the no. of books.7
# The cost of one notebook - $2.
# So the Totoal amount to be paid is 14

# %%
# Shubh is excited to do something mathematical in python. He decided to create a program that could add, subtract, multiply and divide two numbers.
# To help Shubh write a python program to apply addition, subtraction, multiplication, and division between two numbers.
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))
print(f"Addition: {num1 + num2}")
print(f"Subtraction: {num1 - num2}")
print(f"Multiplication: {num1 * num2}")
if num2  != 0:
  print(f"Division: {num1 / num2}")
else:
  print("Division by zero is not allowed.")
# Out:
# Enter the first number: 3254
# Enter the second number: 24
# Addition: 3278
# Subtraction: 3230
# Multiplication: 78096
# Division: 135.58333333333334

# %%
# Rakshita wants to calculate her age. So she subtracted her year of birth from the current year. Her classmates also wanted to find their age in the same way.
#So she decides to write a python program where students can input their year of birth, then the program will print their age. Write the same program to find your age and help your classmates in finding their age.
Year_of_birth = int(input("Enter your year of birth: "))
print(f"Your Age is {2024-Year_of_birth}")
# Out:
# Enter your year of birth: 1965
# Your Age is 59
