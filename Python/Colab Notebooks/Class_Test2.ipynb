# %%
# Saisha created a python program where she takes the input from the user and saves it as a text file. But
# the text file which she saves has a limit of very few characters. So she wants to save the sentences after
# removing the spaces between the words and make the first character of each word capital. To help Saisha
# in this program create a python program that can take input from the user, remove the spaces between
# the word, make the first character of each word capital, and print it on the screen
text = input("Enter the text: ")
words = text.split()
capitalized_words = [word.capitalize() for word in words]
result = "".join(capitalized_words)
print(result)
# Out:
# Enter the text: Saisha created a python program where she takes the input from the user and saves it as a text file.
# SaishaCreatedAPythonProgramWhereSheTakesTheInputFromTheUserAndSavesItAsATextFile.

# %%
# Nidhi challenged her friends to check whether a given number is palindrome or not without using string
# manipulation. All her friends were not able to solve this problem. Write a program in python for the same.
# ● Hint: Use a while loop and a temporary variable.
number = int(input("Enter a number: "))
temp = number
reverse = 0
while number > 0:
    remainder = number % 10
    reverse = reverse * 10 + remainder
    number = number // 10

if temp == reverse:
    print("The number is palindrome!")
else:
    print("The number is not palindrome!")
# Out:
# Enter a number: 2561436192
# The number is not palindrome!

# %%
# Shubh is curious to know that how many times the second hand of the clock rotates in one day. He wants to find the answer with programming.
# Write a python program using nested loops to check how many times the second hand of the clock rotates when the hour hand completes one round.
# ( Use loops only to find out the answer )

rotations = 0
for hour in range(24):
  for minute in range(60):
    for sec in range(60):
      if sec == 59:
        rotations += 1
print(f"The second hand rotates in a day {rotations} times.")
# Out:
# The second hand rotates in a day 1440 times.

# %%
# 1st questions
text = input("Enter a sentence: ")
processed_text = ""
capitalize_next = True

for char in text:
    if char.isspace():
        capitalize_next = True
    else:
        if capitalize_next:
            processed_text += char.upper()
            capitalize_next = False
        else:
            processed_text += char.lower()
print("Processed text:", processed_text)
# Out:
# Enter a sentence: name == 'python' if name == 'java' or 'html' or 'css':     print("successful") else:     print("failed")
# Processed text: Name=='python'IfName=='java'Or'html'Or'css':Print("successful")Else:Print("failed")
